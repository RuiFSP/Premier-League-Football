# %%
#imports 
import requests
import pandas as pd
from io import StringIO
from bs4 import BeautifulSoup
from time import sleep
from numpy import random

# %%
years = list(range(2023,2017,-1))
all_matches = []

# %%
headers = {'User-Agent': 'Mozilla/5.0'}
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
for year in years:
    print(f"---------- This is year: {year}")
    data = requests.get(standings_url,headers=headers)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]
    
    links = [l.get('href') for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    # go for previous season
    previous_seasons = soup.select("a.prev")[0].get('href')
    standings_url = f"https://fbref.com{previous_seasons}"
    
    sleeptime_year = random.uniform(1, 3)
    print("sleeping for:", sleeptime_year, "seconds")
    sleep(sleeptime_year)
    print("sleeping is over")
    
    
    for team_url in team_urls:
        team_name = team_url.split('/')[-1].replace('-Stats', '').replace('-', ' ')
        
        print(f"<<<<<<<< Scraping {team_name}>>>>>>>>")
        
        data = requests.get(team_url)
        matches = pd.read_html(StringIO(data.text), match="Scores & Fixtures")[0]
        
        soup = BeautifulSoup(data.text)
        links = [l.get('href') for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}", headers=headers)
        shooting = pd.read_html(StringIO(data.text), match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        
        
        try:
            team_data = matches.merge(shooting[['Date','PK', 'G/SoT', 'Dist', 'SoT%', 'npxG', 'FK', 'np:G-xG', 'G-xG', 'SoT', 'G/Sh', 'Sh', 'PKatt', 'npxG/Sh', 'Gls']], on='Date')
        
        except ValueError:
            # some teams might not have shooting stats, we will ignore it for now
            continue
        
        # filter for league only
        team_data = team_data[team_data['Comp'] == 'Premier League']
        team_data['Season'] = year
        team_data['Team'] = team_name
        all_matches.append(team_data)
        
        sleeptime = random.uniform(2, 4)
        print("sleeping for:", sleeptime, "seconds")
        sleep(sleeptime)
        print("sleeping is over")
# Out:
# ---------- This is year: 2023
# sleeping for: 1.8044872692924683 seconds
# sleeping is over
# <<<<<<<< Scraping Manchester City>>>>>>>>
# sleeping for: 3.133579058599105 seconds
# sleeping is over
# <<<<<<<< Scraping Liverpool>>>>>>>>
# sleeping for: 2.053377093918843 seconds
# sleeping is over
# <<<<<<<< Scraping Arsenal>>>>>>>>
# sleeping for: 2.2833311884144623 seconds
# sleeping is over
# <<<<<<<< Scraping Tottenham Hotspur>>>>>>>>
# sleeping for: 3.5083039906025704 seconds
# sleeping is over
# <<<<<<<< Scraping Aston Villa>>>>>>>>
# sleeping for: 3.151691126729576 seconds
# sleeping is over
# <<<<<<<< Scraping Manchester United>>>>>>>>
# sleeping for: 3.677387317575427 seconds
# sleeping is over
# <<<<<<<< Scraping Newcastle United>>>>>>>>
# sleeping for: 3.233823364817783 seconds
# sleeping is over
# <<<<<<<< Scraping Brighton and Hove Albion>>>>>>>>
# sleeping for: 2.8619220970148644 seconds
# sleeping is over
# <<<<<<<< Scraping West Ham United>>>>>>>>
# sleeping for: 2.834593314479096 seconds
# sleeping is over
# <<<<<<<< Scraping Chelsea>>>>>>>>
# sleeping for: 3.9267031906253558 seconds
# sleeping is over
# <<<<<<<< Scraping Brentford>>>>>>>>
# sleeping for: 3.7577416584764656 seconds
# sleeping is over
# <<<<<<<< Scraping Wolverhampton Wanderers>>>>>>>>
# sleeping for: 3.671801847795944 seconds
# sleeping is over
# <<<<<<<< Scraping Crystal Palace>>>>>>>>
# sleeping for: 2.983924193225632 seconds
# sleeping is over
# <<<<<<<< Scraping Everton>>>>>>>>
# sleeping for: 2.875263864316568 seconds
# sleeping is over
# <<<<<<<< Scraping Nottingham Forest>>>>>>>>
# sleeping for: 3.9516527759409925 seconds
# sleeping is over
# <<<<<<<< Scraping Fulham>>>>>>>>
# sleeping for: 2.6730408832601196 seconds
# sleeping is over
# <<<<<<<< Scraping Bournemouth>>>>>>>>
# sleeping for: 3.7501308420925876 seconds
# sleeping is over
# <<<<<<<< Scraping Luton Town>>>>>>>>
# sleeping for: 3.7566848468896046 seconds
# sleeping is over
# <<<<<<<< Scraping Sheffield United>>>>>>>>
# sleeping for: 2.527717164222439 seconds
# sleeping is over
# <<<<<<<< Scraping Burnley>>>>>>>>
# sleeping for: 3.563939949044678 seconds
# sleeping is over
# ---------- This is year: 2022
# sleeping for: 1.1859156621040015 seconds
# sleeping is over
# <<<<<<<< Scraping Manchester City>>>>>>>>
# sleeping for: 2.6257339021592623 seconds
# sleeping is over
# <<<<<<<< Scraping Arsenal>>>>>>>>
# sleeping for: 2.303180700468718 seconds
# sleeping is over
# <<<<<<<< Scraping Manchester United>>>>>>>>
# sleeping for: 2.340049540243813 seconds
# sleeping is over
# <<<<<<<< Scraping Newcastle United>>>>>>>>
# sleeping for: 2.6856932312786834 seconds
# sleeping is over
# <<<<<<<< Scraping Liverpool>>>>>>>>
# sleeping for: 3.170497130014091 seconds
# sleeping is over
# <<<<<<<< Scraping Brighton and Hove Albion>>>>>>>>
# sleeping for: 3.271037277775711 seconds
# sleeping is over
# <<<<<<<< Scraping Aston Villa>>>>>>>>
# sleeping for: 3.0077722633795156 seconds
# sleeping is over
# <<<<<<<< Scraping Tottenham Hotspur>>>>>>>>
# sleeping for: 2.7763243637183708 seconds
# sleeping is over
# <<<<<<<< Scraping Brentford>>>>>>>>
# sleeping for: 3.247454497471863 seconds
# sleeping is over
# <<<<<<<< Scraping Fulham>>>>>>>>
# sleeping for: 2.0854969614059113 seconds
# sleeping is over
# <<<<<<<< Scraping Crystal Palace>>>>>>>>
# sleeping for: 2.3529509666062065 seconds
# sleeping is over
# <<<<<<<< Scraping Chelsea>>>>>>>>
# sleeping for: 3.0432454546770487 seconds
# sleeping is over
# <<<<<<<< Scraping Wolverhampton Wanderers>>>>>>>>
# sleeping for: 3.2924839317519683 seconds
# sleeping is over
# <<<<<<<< Scraping West Ham United>>>>>>>>
# sleeping for: 2.488195146016142 seconds
# sleeping is over
# <<<<<<<< Scraping Bournemouth>>>>>>>>
# sleeping for: 2.883363555997553 seconds
# sleeping is over
# <<<<<<<< Scraping Nottingham Forest>>>>>>>>
# sleeping for: 2.4897947850910604 seconds
# sleeping is over
# <<<<<<<< Scraping Everton>>>>>>>>
# sleeping for: 2.1943012378082174 seconds
# sleeping is over
# <<<<<<<< Scraping Leicester City>>>>>>>>
# sleeping for: 2.95767600115712 seconds
# sleeping is over
# <<<<<<<< Scraping Leeds United>>>>>>>>
# sleeping for: 3.995870006468547 seconds
# sleeping is over
# <<<<<<<< Scraping Southampton>>>>>>>>
# sleeping for: 3.1835814329324705 seconds
# sleeping is over
# ---------- This is year: 2021
# sleeping for: 2.3819832529321516 seconds
# sleeping is over
# <<<<<<<< Scraping Manchester City>>>>>>>>
# sleeping for: 2.149528870127952 seconds
# sleeping is over
# <<<<<<<< Scraping Liverpool>>>>>>>>
# sleeping for: 2.3126512952850424 seconds
# sleeping is over
# <<<<<<<< Scraping Chelsea>>>>>>>>
# sleeping for: 2.7028885125264157 seconds
# sleeping is over
# <<<<<<<< Scraping Tottenham Hotspur>>>>>>>>
# sleeping for: 2.127429610145346 seconds
# sleeping is over
# <<<<<<<< Scraping Arsenal>>>>>>>>
# sleeping for: 2.0988294403142946 seconds
# sleeping is over
# <<<<<<<< Scraping Manchester United>>>>>>>>
# sleeping for: 2.4789723690388454 seconds
# sleeping is over
# <<<<<<<< Scraping West Ham United>>>>>>>>
# sleeping for: 2.107616270657102 seconds
# sleeping is over
# <<<<<<<< Scraping Leicester City>>>>>>>>
# sleeping for: 2.0126035458420435 seconds
# sleeping is over
# <<<<<<<< Scraping Brighton and Hove Albion>>>>>>>>
# sleeping for: 3.757638718014836 seconds
# sleeping is over
# <<<<<<<< Scraping Wolverhampton Wanderers>>>>>>>>
# sleeping for: 2.2172901518644244 seconds
# sleeping is over
# <<<<<<<< Scraping Newcastle United>>>>>>>>
# sleeping for: 2.3958330759366047 seconds
# sleeping is over
# <<<<<<<< Scraping Crystal Palace>>>>>>>>
# sleeping for: 2.6009262954958814 seconds
# sleeping is over
# <<<<<<<< Scraping Brentford>>>>>>>>
# sleeping for: 2.9554745224598924 seconds
# sleeping is over
# <<<<<<<< Scraping Aston Villa>>>>>>>>
# sleeping for: 3.7348299187756413 seconds
# sleeping is over
# <<<<<<<< Scraping Southampton>>>>>>>>
# sleeping for: 2.268204841224891 seconds
# sleeping is over
# <<<<<<<< Scraping Everton>>>>>>>>
# sleeping for: 2.5143700998078717 seconds
# sleeping is over
# <<<<<<<< Scraping Leeds United>>>>>>>>
# sleeping for: 2.817068002134026 seconds
# sleeping is over
# <<<<<<<< Scraping Burnley>>>>>>>>
# sleeping for: 3.293853385560194 seconds
# sleeping is over
# <<<<<<<< Scraping Watford>>>>>>>>
# sleeping for: 2.02498811155599 seconds
# sleeping is over
# <<<<<<<< Scraping Norwich City>>>>>>>>
# sleeping for: 3.8275548210979613 seconds
# sleeping is over
# ---------- This is year: 2020
# sleeping for: 2.319160370773938 seconds
# sleeping is over
# <<<<<<<< Scraping Manchester City>>>>>>>>
# sleeping for: 2.800587758483994 seconds
# sleeping is over
# <<<<<<<< Scraping Manchester United>>>>>>>>
# sleeping for: 3.2141415697788354 seconds
# sleeping is over
# <<<<<<<< Scraping Liverpool>>>>>>>>
# sleeping for: 2.9381643539158873 seconds
# sleeping is over
# <<<<<<<< Scraping Chelsea>>>>>>>>
# sleeping for: 3.9192410915509273 seconds
# sleeping is over
# <<<<<<<< Scraping Leicester City>>>>>>>>
# sleeping for: 3.9243708247165587 seconds
# sleeping is over
# <<<<<<<< Scraping West Ham United>>>>>>>>
# sleeping for: 2.331948531043767 seconds
# sleeping is over
# <<<<<<<< Scraping Tottenham Hotspur>>>>>>>>
# sleeping for: 2.652251342911402 seconds
# sleeping is over
# <<<<<<<< Scraping Arsenal>>>>>>>>
# sleeping for: 3.4770423458732442 seconds
# sleeping is over
# <<<<<<<< Scraping Leeds United>>>>>>>>
# sleeping for: 3.820647496932396 seconds
# sleeping is over
# <<<<<<<< Scraping Everton>>>>>>>>
# sleeping for: 2.450199151015492 seconds
# sleeping is over
# <<<<<<<< Scraping Aston Villa>>>>>>>>
# sleeping for: 3.503497831851423 seconds
# sleeping is over
# <<<<<<<< Scraping Newcastle United>>>>>>>>
# sleeping for: 2.5446527249325714 seconds
# sleeping is over
# <<<<<<<< Scraping Wolverhampton Wanderers>>>>>>>>
# sleeping for: 3.5953896046190685 seconds
# sleeping is over
# <<<<<<<< Scraping Crystal Palace>>>>>>>>
# sleeping for: 3.8101791740029993 seconds
# sleeping is over
# <<<<<<<< Scraping Southampton>>>>>>>>
# sleeping for: 2.2418757731404284 seconds
# sleeping is over
# <<<<<<<< Scraping Brighton and Hove Albion>>>>>>>>
# sleeping for: 2.9673112269028015 seconds
# sleeping is over
# <<<<<<<< Scraping Burnley>>>>>>>>
# sleeping for: 3.219930595338885 seconds
# sleeping is over
# <<<<<<<< Scraping Fulham>>>>>>>>
# sleeping for: 2.772316924755266 seconds
# sleeping is over
# <<<<<<<< Scraping West Bromwich Albion>>>>>>>>
# sleeping for: 2.555933886745827 seconds
# sleeping is over
# <<<<<<<< Scraping Sheffield United>>>>>>>>
# sleeping for: 3.1308194517117074 seconds
# sleeping is over
# ---------- This is year: 2019
# sleeping for: 1.6873828547516145 seconds
# sleeping is over
# <<<<<<<< Scraping Liverpool>>>>>>>>
# sleeping for: 3.7235904700385842 seconds
# sleeping is over
# <<<<<<<< Scraping Manchester City>>>>>>>>
# sleeping for: 3.3099082622269993 seconds
# sleeping is over
# <<<<<<<< Scraping Manchester United>>>>>>>>
# sleeping for: 2.4920219072478664 seconds
# sleeping is over
# <<<<<<<< Scraping Chelsea>>>>>>>>
# sleeping for: 3.8226378195880786 seconds
# sleeping is over
# <<<<<<<< Scraping Leicester City>>>>>>>>
# sleeping for: 2.1244443252612273 seconds
# sleeping is over
# <<<<<<<< Scraping Tottenham Hotspur>>>>>>>>
# sleeping for: 3.617150112764532 seconds
# sleeping is over
# <<<<<<<< Scraping Wolverhampton Wanderers>>>>>>>>
# sleeping for: 3.8613674754087794 seconds
# sleeping is over
# <<<<<<<< Scraping Arsenal>>>>>>>>
# sleeping for: 2.7392210085962834 seconds
# sleeping is over
# <<<<<<<< Scraping Sheffield United>>>>>>>>
# sleeping for: 3.071810932492948 seconds
# sleeping is over
# <<<<<<<< Scraping Burnley>>>>>>>>
# sleeping for: 3.468482058977336 seconds
# sleeping is over
# <<<<<<<< Scraping Southampton>>>>>>>>
# sleeping for: 2.886511756702488 seconds
# sleeping is over
# <<<<<<<< Scraping Everton>>>>>>>>
# sleeping for: 2.449054384088596 seconds
# sleeping is over
# <<<<<<<< Scraping Newcastle United>>>>>>>>
# sleeping for: 2.0870290805422114 seconds
# sleeping is over
# <<<<<<<< Scraping Crystal Palace>>>>>>>>
# sleeping for: 3.5935127668045217 seconds
# sleeping is over
# <<<<<<<< Scraping Brighton and Hove Albion>>>>>>>>
# sleeping for: 3.191422084618268 seconds
# sleeping is over
# <<<<<<<< Scraping West Ham United>>>>>>>>
# sleeping for: 3.3084136084061013 seconds
# sleeping is over
# <<<<<<<< Scraping Aston Villa>>>>>>>>
# sleeping for: 3.8972429513968936 seconds
# sleeping is over
# <<<<<<<< Scraping Bournemouth>>>>>>>>
# sleeping for: 2.337792049620564 seconds
# sleeping is over
# <<<<<<<< Scraping Watford>>>>>>>>
# sleeping for: 3.7964234333530356 seconds
# sleeping is over
# <<<<<<<< Scraping Norwich City>>>>>>>>
# sleeping for: 2.413397629471387 seconds
# sleeping is over
# ---------- This is year: 2018
# sleeping for: 1.4133148032171892 seconds
# sleeping is over
# <<<<<<<< Scraping Manchester City>>>>>>>>
# sleeping for: 3.3433694882621676 seconds
# sleeping is over
# <<<<<<<< Scraping Liverpool>>>>>>>>
# sleeping for: 3.1617586635410957 seconds
# sleeping is over
# <<<<<<<< Scraping Chelsea>>>>>>>>
# sleeping for: 3.887855093043682 seconds
# sleeping is over
# <<<<<<<< Scraping Tottenham Hotspur>>>>>>>>
# sleeping for: 3.7673339877041983 seconds
# sleeping is over
# <<<<<<<< Scraping Arsenal>>>>>>>>
# sleeping for: 3.3401084420493974 seconds
# sleeping is over
# <<<<<<<< Scraping Manchester United>>>>>>>>
# sleeping for: 2.2242816898974183 seconds
# sleeping is over
# <<<<<<<< Scraping Wolverhampton Wanderers>>>>>>>>
# sleeping for: 3.857384164881942 seconds
# sleeping is over
# <<<<<<<< Scraping Everton>>>>>>>>
# sleeping for: 3.033262943212216 seconds
# sleeping is over
# <<<<<<<< Scraping Leicester City>>>>>>>>
# sleeping for: 2.980228134449838 seconds
# sleeping is over
# <<<<<<<< Scraping West Ham United>>>>>>>>
# sleeping for: 2.8598979522647276 seconds
# sleeping is over
# <<<<<<<< Scraping Watford>>>>>>>>
# sleeping for: 3.4471065778988677 seconds
# sleeping is over
# <<<<<<<< Scraping Crystal Palace>>>>>>>>
# sleeping for: 2.4392804939121078 seconds
# sleeping is over
# <<<<<<<< Scraping Newcastle United>>>>>>>>
# sleeping for: 3.695286869717373 seconds
# sleeping is over
# <<<<<<<< Scraping Bournemouth>>>>>>>>
# sleeping for: 3.012136665806039 seconds
# sleeping is over
# <<<<<<<< Scraping Burnley>>>>>>>>
# sleeping for: 3.5626649786031583 seconds
# sleeping is over
# <<<<<<<< Scraping Southampton>>>>>>>>
# sleeping for: 2.6232443704598163 seconds
# sleeping is over
# <<<<<<<< Scraping Brighton and Hove Albion>>>>>>>>
# sleeping for: 2.9994632506041263 seconds
# sleeping is over
# <<<<<<<< Scraping Cardiff City>>>>>>>>
# sleeping for: 3.102566182730663 seconds
# sleeping is over
# <<<<<<<< Scraping Fulham>>>>>>>>
# sleeping for: 3.9821311552702796 seconds
# sleeping is over
# <<<<<<<< Scraping Huddersfield Town>>>>>>>>
# sleeping for: 3.237006330451231 seconds
# sleeping is over

# %%
# combine all the dataframes
matches_df = pd.concat(all_matches)

# %%
# lower case column names
matches_df.columns = [c.lower() for c in matches_df.columns]

# %%
matches_df.shape
# Out:
# (4040, 35)

# %%
matches_df.tail()
# Out:
#           date   time            comp         round  day venue result gf ga  \
# 35  2019-04-13  12:30  Premier League  Matchweek 34  Sat  Away      L  0  4
# 36  2019-04-20  15:00  Premier League  Matchweek 35  Sat  Home      L  1  2
# 37  2019-04-26  20:00  Premier League  Matchweek 36  Fri  Away      L  0  5
# 38  2019-05-05  14:00  Premier League  Matchweek 37  Sun  Home      D  1  1
# 39  2019-05-12  15:00  Premier League  Matchweek 38  Sun  Away      D  1  1
#
#           opponent  ...  np:g-xg  g-xg  sot  g/sh    sh pkatt npxg/sh gls  \
# 35       Tottenham  ...     -0.8  -0.8  1.0  0.00   7.0     0    0.11   0
# 36         Watford  ...      0.0   0.0  3.0  0.08  13.0     0    0.08   1
# 37       Liverpool  ...     -0.2  -0.2  1.0  0.00   5.0     0    0.04   0
# 38  Manchester Utd  ...      0.0   0.0  3.0  0.14   7.0     0    0.14   1
# 39     Southampton  ...      0.3   0.3  3.0  0.10  10.0     0    0.07   1
#
#    season               team
# 35   2018  Huddersfield Town
# 36   2018  Huddersfield Town
# 37   2018  Huddersfield Town
# 38   2018  Huddersfield Town
# 39   2018  Huddersfield Town
#
# [5 rows x 35 columns]

# %%
matches_df.to_csv('data/matches_18_23.csv', index=False)

# %%
matches_df.head()
# Out:
#          date   time            comp        round  day venue result gf ga  \
# 1  2023-08-11  20:00  Premier League  Matchweek 1  Fri  Away      W  3  0
# 3  2023-08-19  20:00  Premier League  Matchweek 2  Sat  Home      W  1  0
# 4  2023-08-27  14:00  Premier League  Matchweek 3  Sun  Away      W  2  1
# 5  2023-09-02  15:00  Premier League  Matchweek 4  Sat  Home      W  5  1
# 6  2023-09-16  15:00  Premier League  Matchweek 5  Sat  Away      W  3  1
#
#         opponent  ...  np:g-xg  g-xg   sot  g/sh    sh pkatt npxg/sh gls  \
# 1        Burnley  ...      1.1   1.1   8.0  0.18  17.0     0    0.12   3
# 3  Newcastle Utd  ...      0.0   0.0   4.0  0.07  14.0     0    0.07   1
# 4  Sheffield Utd  ...     -0.8  -1.5   9.0  0.07  29.0     1    0.10   2
# 5         Fulham  ...      2.6   2.8   4.0  0.67   6.0     1    0.25   5
# 6       West Ham  ...     -0.6  -0.6  13.0  0.10  29.0     0    0.13   3
#
#   season             team
# 1   2023  Manchester City
# 3   2023  Manchester City
# 4   2023  Manchester City
# 5   2023  Manchester City
# 6   2023  Manchester City
#
# [5 rows x 35 columns]
