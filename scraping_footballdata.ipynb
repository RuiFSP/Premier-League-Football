# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://www.football-data.co.uk/englandm.php"

# %%
data = requests.get(url)

# %%
soup = BeautifulSoup(data.text)

# %%
# Define the base URL and the season numbers
base_url = "https://www.football-data.co.uk/mmz4281/{}/E0.csv"
seasons = ["1718","1819", "1920","2021","2122", "2223", "2324"] # Add more seasons as needed

# Loop through the seasons and scrape the csv files
for season in seasons:
    url = base_url.format(season)
    response = requests.get(url)
    with open(f"./data/Premier_League_{season}.csv", "wb") as f:
        f.write(response.content)

# %%
df = pd.read_csv("./data/Premier_League_1920.csv")

# %%
# we just want the prices
df.columns
# Out:
# Index(['Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR',
#        'HTHG', 'HTAG',
#        ...
#        'AvgC<2.5', 'AHCh', 'B365CAHH', 'B365CAHA', 'PCAHH', 'PCAHA', 'MaxCAHH',
#        'MaxCAHA', 'AvgCAHH', 'AvgCAHA'],
#       dtype='object', length=106)

# %%
columns_to_select = ['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','B365H','B365D','B365A','B365>2.5','B365<2.5','PSH','PSD','PSA','P>2.5','P<2.5']

# %%
df[columns_to_select].head()
# Out:
#          Date   Time        HomeTeam          AwayTeam  FTHG  FTAG FTR  B365H  \
# 0  09/08/2019  20:00       Liverpool           Norwich     4     1   H   1.14
# 1  10/08/2019  12:30        West Ham          Man City     0     5   A  12.00
# 2  10/08/2019  15:00     Bournemouth  Sheffield United     1     1   D   1.95
# 3  10/08/2019  15:00         Burnley       Southampton     3     0   H   2.62
# 4  10/08/2019  15:00  Crystal Palace           Everton     0     0   D   3.00
#
#    B365D  B365A  B365>2.5  B365<2.5    PSH   PSD    PSA  P>2.5  P<2.5
# 0  10.00  19.00      1.40      3.00   1.15  9.59  18.05   1.40   3.11
# 1   6.50   1.22      1.44      2.75  11.68  6.53   1.26   1.49   2.77
# 2   3.60   3.60      1.90      1.90   2.04  3.57   3.90   1.96   1.96
# 3   3.20   2.75      2.10      1.72   2.71  3.31   2.81   2.17   1.77
# 4   3.25   2.37      2.20      1.66   3.21  3.37   2.39   2.23   1.74

# %%
import pandas as pd
import glob

base_url = "./data/Premier_League_{}.csv"
seasons = ["1718","1819", "1920","2021","2122", "2223", "2324"]  # Add more seasons as needed
year = []

# Create an empty list to store the dataframes
dfs = []

# Loop through the seasons and read the csv files
for season in seasons:
    file_path = base_url.format(season)
    df = pd.read_csv(file_path, usecols=columns_to_select)
    # Add a column with the season number that is determined my seaons first two digit , so it should be 23 -> 2023
    df["Season"] = "20" + season[:2]

    dfs.append(df)

# Concatenate the dataframes on index
result = pd.concat(dfs, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/ruifspinto/Desktop/football_predictions/scraping_footballdata.ipynb Cell 10 line 1
#      <a href='vscode-notebook-cell:/Users/ruifspinto/Desktop/football_predictions/scraping_footballdata.ipynb#X12sZmlsZQ%3D%3D?line=11'>12</a> for season in seasons:
#      <a href='vscode-notebook-cell:/Users/ruifspinto/Desktop/football_predictions/scraping_footballdata.ipynb#X12sZmlsZQ%3D%3D?line=12'>13</a>     file_path = base_url.format(season)
# ---> <a href='vscode-notebook-cell:/Users/ruifspinto/Desktop/football_predictions/scraping_footballdata.ipynb#X12sZmlsZQ%3D%3D?line=13'>14</a>     df = pd.read_csv(file_path, usecols=columns_to_select)
#      <a href='vscode-notebook-cell:/Users/ruifspinto/Desktop/football_predictions/scraping_footballdata.ipynb#X12sZmlsZQ%3D%3D?line=14'>15</a>     # Add a column with the season number that is determined my seaons first two digit , so it should be 23 -> 2023
#      <a href='vscode-notebook-cell:/Users/ruifspinto/Desktop/football_predictions/scraping_footballdata.ipynb#X12sZmlsZQ%3D%3D?line=15'>16</a>     df["Season"] = "20" + season[:2]
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/io/parsers/readers.py:678, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     663 kwds_defaults = _refine_defaults_read(
#     664     dialect,
#     665     delimiter,
#    (...)
#     674     defaults={"delimiter": ","},
#     675 )
#     676 kwds.update(kwds_defaults)
# --> 678 return _read(filepath_or_buffer, kwds)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/io/parsers/readers.py:932, in TextFileReader.__init__(self, f, engine, **kwds)
#     929     self.options["has_index_names"] = kwds["has_index_names"]
#     931 self.handles: IOHandles | None = None
# --> 932 self._engine = self._make_engine(f, self.engine)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1234, in TextFileReader._make_engine(self, f, engine)
#    1231     raise ValueError(msg)
#    1233 try:
# -> 1234     return mapping[engine](f, **self.options)
#    1235 except Exception:
#    1236     if self.handles is not None:
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:131, in CParserWrapper.__init__(self, src, **kwds)
#     127 assert self.orig_names is not None
#     128 if self.usecols_dtype == "string" and not set(usecols).issubset(
#     129     self.orig_names
#     130 ):
# --> 131     self._validate_usecols_names(usecols, self.orig_names)
#     133 # error: Cannot determine type of 'names'
#     134 if len(self.names) > len(usecols):  # type: ignore[has-type]
#     135     # error: Cannot determine type of 'names'
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/io/parsers/base_parser.py:913, in ParserBase._validate_usecols_names(self, usecols, names)
#     911 missing = [c for c in usecols if c not in names]
#     912 if len(missing) > 0:
# --> 913     raise ValueError(
#     914         f"Usecols do not match columns, columns expected but not found: "
#     915         f"{missing}"
#     916     )
#     918 return usecols
#
# ValueError: Usecols do not match columns, columns expected but not found: ['P<2.5', 'B365<2.5', 'B365>2.5', 'P>2.5']

# %%
result.shape
# Out:
# (1640, 18)

# %%
result
# Out:
#             Date   Time        HomeTeam          AwayTeam  FTHG  FTAG FTR  \
# 0     09/08/2019  20:00       Liverpool           Norwich     4     1   H
# 1     10/08/2019  12:30        West Ham          Man City     0     5   A
# 2     10/08/2019  15:00     Bournemouth  Sheffield United     1     1   D
# 3     10/08/2019  15:00         Burnley       Southampton     3     0   H
# 4     10/08/2019  15:00  Crystal Palace           Everton     0     0   D
# ...          ...    ...             ...               ...   ...   ...  ..
# 1635  12/11/2023  14:00     Aston Villa            Fulham     3     1   H
# 1636  12/11/2023  14:00        Brighton  Sheffield United     1     1   D
# 1637  12/11/2023  14:00       Liverpool         Brentford     3     0   H
# 1638  12/11/2023  14:00        West Ham     Nott'm Forest     3     2   H
# 1639  12/11/2023  16:30         Chelsea          Man City     4     4   D
#
#       B365H  B365D  B365A    PSH   PSD    PSA  B365>2.5  B365<2.5  P>2.5  \
# 0      1.14  10.00  19.00   1.15  9.59  18.05      1.40      3.00   1.40
# 1     12.00   6.50   1.22  11.68  6.53   1.26      1.44      2.75   1.49
# 2      1.95   3.60   3.60   2.04  3.57   3.90      1.90      1.90   1.96
# 3      2.62   3.20   2.75   2.71  3.31   2.81      2.10      1.72   2.17
# 4      3.00   3.25   2.37   3.21  3.37   2.39      2.20      1.66   2.23
# ...     ...    ...    ...    ...   ...    ...       ...       ...    ...
# 1635   1.57   4.20   5.50   1.60  4.27   5.67      1.70      2.10   1.74
# 1636   1.25   5.75  13.00   1.24  6.80  11.28      1.40      2.88   1.42
# 1637   1.40   5.00   6.50   1.41  5.26   7.17      1.44      2.70   1.47
# 1638   1.85   3.60   4.00   1.89  3.79   4.10      1.75      2.05   1.81
# 1639   5.00   3.70   1.73   4.92  3.80   1.75      1.88      2.02   1.88
#
#       P<2.5 Season
# 0      3.11   2019
# 1      2.77   2019
# 2      1.96   2019
# 3      1.77   2019
# 4      1.74   2019
# ...     ...    ...
# 1635   2.17   2023
# 1636   2.92   2023
# 1637   2.77   2023
# 1638   2.07   2023
# 1639   2.01   2023
#
# [1640 rows x 18 columns]

# %%
result.groupby("Season").count()
# Out:
#         Date  Time  HomeTeam  AwayTeam  FTHG  FTAG  FTR  B365H  B365D  B365A  \
# Season
# 2019     380   380       380       380   380   380  380    380    380    380
# 2020     380   380       380       380   380   380  380    380    380    380
# 2021     380   380       380       380   380   380  380    380    380    380
# 2022     380   380       380       380   380   380  380    380    380    380
# 2023     120   120       120       120   120   120  120    120    120    120
#
#         PSH  PSD  PSA  B365>2.5  B365<2.5  P>2.5  P<2.5
# Season
# 2019    380  380  380       380       380    380    380
# 2020    380  380  380       380       380    380    380
# 2021    380  380  380       379       379    380    380
# 2022    380  380  380       380       380    379    379
# 2023    120  120  120       120       120    120    120

# %%
# save the data
result.to_csv("./data/football_data.csv", index=False)
